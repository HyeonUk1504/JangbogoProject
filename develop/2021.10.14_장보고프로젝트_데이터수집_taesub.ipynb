# %%
import pandas as pd

# %%
fresh=pd.read_csv("C:/Users/limok/jangbogo/신선식품지수_2010.2021.09.csv", encoding="cp949", skiprows=1)
fresh
# Out:
#            시점      총지수     신선식품     신선어개     신선채소     신선과실   신선식품제외
# 0    2010. 01   89.974   85.417   85.995   91.655   82.400   90.134
# 1    2010. 02   90.156   89.206   87.666   98.428   85.040   90.225
# 2    2010. 03   90.338   92.219   86.962  107.167   86.077   90.316
# 3    2010. 04   90.702   96.300   88.545  112.192   91.168   90.497
# 4    2010. 05   90.793   94.357   88.105  100.722   95.505   90.679
# ..        ...      ...      ...      ...      ...      ...      ...
# 136  2021. 05  107.460  128.820  121.000  124.590  138.170  106.590
# 137  2021. 06  107.390  122.270  120.410  116.120  129.600  106.790
# 138  2021. 07  107.610  120.500  118.160  115.390  127.110  107.070
# 139  2021. 08  108.290  129.180  117.560  129.170  136.790  107.440
# 140  2021. 09  108.830  136.770  118.610  147.470  138.020  107.710
#
# [141 rows x 7 columns]

# %%
all_consumer=pd.read_csv("C:/Users/limok/jangbogo/소비자물가지수__2010.2021.09.csv", encoding="cp949")
all_consumer
# Out:
#            시점       전국    서울특별시    부산광역시    대구광역시    인천광역시    광주광역시    대전광역시  \
# 0    2010. 01   89.974   88.974   89.047   89.050   90.319   90.187   90.707
# 1    2010. 02   90.156   89.154   89.318   89.321   90.593   90.461   90.799
# 2    2010. 03   90.338   89.515   89.589   89.591   90.777   90.827   90.983
# 3    2010. 04   90.702   89.875   89.859   89.862   91.235   91.102   91.534
# 4    2010. 05   90.793   89.875   89.949   90.042   91.326   91.193   91.626
# ..        ...      ...      ...      ...      ...      ...      ...      ...
# 136  2021. 05  107.460  107.370  107.570  107.950  107.570  107.320  106.770
# 137  2021. 06  107.390  107.250  107.330  107.850  107.540  107.180  106.770
# 138  2021. 07  107.610  107.450  107.580  108.060  107.720  107.380  107.030
# 139  2021. 08  108.290  108.090  108.110  108.870  108.390  107.990  107.520
# 140  2021. 09  108.830  108.590  108.960  109.500  109.060  108.490  107.920
#
# ...

# %%
all_consumer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시점       141 non-null    object
#  1   전국       141 non-null    float64
#  2   서울특별시    141 non-null    float64
#  3   부산광역시    141 non-null    float64
#  4   대구광역시    141 non-null    float64
#  5   인천광역시    141 non-null    float64
#  6   광주광역시    141 non-null    float64
#  7   대전광역시    141 non-null    float64
#  8   울산광역시    141 non-null    float64
#  9   경기도      141 non-null    float64
#  10  강원도      141 non-null    float64
#  11  충청북도     141 non-null    float64
#  12  충청남도     141 non-null    float64
#  13  전라북도     141 non-null    float64
#  14  전라남도     141 non-null    float64
#  15  경상북도     141 non-null    float64
#  16  경상남도     141 non-null    float64
#  17  제주특별자치도  141 non-null    float64
# dtypes: float64(17), object(1)
# memory usage: 20.0+ KB

# %%
all_consumer["연도"]=all_consumer.시점.str.split(".").str[0]

# %%
fresh["연도"]=fresh.시점.str.split(".").str[0]

# %%
all_consumer
# Out:
#            시점       전국    서울특별시    부산광역시    대구광역시    인천광역시    광주광역시    대전광역시  \
# 0    2010. 01   89.974   88.974   89.047   89.050   90.319   90.187   90.707
# 1    2010. 02   90.156   89.154   89.318   89.321   90.593   90.461   90.799
# 2    2010. 03   90.338   89.515   89.589   89.591   90.777   90.827   90.983
# 3    2010. 04   90.702   89.875   89.859   89.862   91.235   91.102   91.534
# 4    2010. 05   90.793   89.875   89.949   90.042   91.326   91.193   91.626
# ..        ...      ...      ...      ...      ...      ...      ...      ...
# 136  2021. 05  107.460  107.370  107.570  107.950  107.570  107.320  106.770
# 137  2021. 06  107.390  107.250  107.330  107.850  107.540  107.180  106.770
# 138  2021. 07  107.610  107.450  107.580  108.060  107.720  107.380  107.030
# 139  2021. 08  108.290  108.090  108.110  108.870  108.390  107.990  107.520
# 140  2021. 09  108.830  108.590  108.960  109.500  109.060  108.490  107.920
#
# ...

# %%
fresh
# Out:
#            시점      총지수     신선식품     신선어개     신선채소     신선과실   신선식품제외    연도
# 0    2010. 01   89.974   85.417   85.995   91.655   82.400   90.134  2010
# 1    2010. 02   90.156   89.206   87.666   98.428   85.040   90.225  2010
# 2    2010. 03   90.338   92.219   86.962  107.167   86.077   90.316  2010
# 3    2010. 04   90.702   96.300   88.545  112.192   91.168   90.497  2010
# 4    2010. 05   90.793   94.357   88.105  100.722   95.505   90.679  2010
# ..        ...      ...      ...      ...      ...      ...      ...   ...
# 136  2021. 05  107.460  128.820  121.000  124.590  138.170  106.590  2021
# 137  2021. 06  107.390  122.270  120.410  116.120  129.600  106.790  2021
# 138  2021. 07  107.610  120.500  118.160  115.390  127.110  107.070  2021
# 139  2021. 08  108.290  129.180  117.560  129.170  136.790  107.440  2021
# 140  2021. 09  108.830  136.770  118.610  147.470  138.020  107.710  2021
#
# [141 rows x 8 columns]

# %%
import plotly.express as px
fig = px.bar(all_consumer, x='시점', y='전국',
            color='연도',
             labels={"전국 소비자 물가지수"}, height=600, width=1000)
fig.show()
# Out:
# <div>                            <div id="245c5091-5d04-4d9e-ac7e-8620c5d787da" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("245c5091-5d04-4d9e-ac7e-8620c5d787da")) {                    Plotly.newPlot(                        "245c5091-5d04-4d9e-ac7e-8620c5d787da",                        [{"alignmentgroup":"True","hovertemplate":"\uc5f0\ub3c4=2010<br>\uc2dc\uc810=%{x}<br>\uc804\uad6d=%{y}<extra></extra>","legendgroup":"2010","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2010","offsetgroup":"2010","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["2010. 01","2010. 02","2010. 03","2010. 04","2010. 05","2010. 06","2010. 07","2010. 08","2010. 09","2010. 10","2010. 11","2010. 12"],"xaxis":"x","y":[89.974,90.156
# ...

# %%
fig = px.line(all_consumer, x="시점", y="전국")

fig.show()
# Out:
# <div>                            <div id="6e6f850b-abfb-4b8f-9ad1-d6ae1e44d6ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e6f850b-abfb-4b8f-9ad1-d6ae1e44d6ae")) {                    Plotly.newPlot(                        "6e6f850b-abfb-4b8f-9ad1-d6ae1e44d6ae",                        [{"hovertemplate":"\uc2dc\uc810=%{x}<br>\uc804\uad6d=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":["2010. 01","2010. 02","2010. 03","2010. 04","2010. 05","2010. 06","2010. 07","2010. 08","2010. 09","2010. 10","2010. 11","2010. 12","2011. 01","2011. 02","2011. 03","2011. 04","2011. 05","2011. 06","2011. 07","2011. 08","2011. 09","2011. 10","2011. 11
# ...

# %%
import plotly.express as px
fig = px.bar(fresh, x='시점', y='총지수',
            color='연도',
             labels={"신선식품지수"}, height=600, width=1000)
fig.show()
# Out:
# <div>                            <div id="8a459a14-44e0-4660-93fb-bb4fb2cbc20e" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a459a14-44e0-4660-93fb-bb4fb2cbc20e")) {                    Plotly.newPlot(                        "8a459a14-44e0-4660-93fb-bb4fb2cbc20e",                        [{"alignmentgroup":"True","hovertemplate":"\uc5f0\ub3c4=2010<br>\uc2dc\uc810=%{x}<br>\ucd1d\uc9c0\uc218=%{y}<extra></extra>","legendgroup":"2010","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2010","offsetgroup":"2010","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["2010. 01","2010. 02","2010. 03","2010. 04","2010. 05","2010. 06","2010. 07","2010. 08","2010. 09","2010. 10","2010. 11","2010. 12"],"xaxis":"x","y":[89.974,
# ...

# %%
fig = px.line(fresh, x="시점", y="총지수")

fig.show()
# Out:
# <div>                            <div id="3a31c20a-01c2-4955-b239-dfb215f310b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a31c20a-01c2-4955-b239-dfb215f310b5")) {                    Plotly.newPlot(                        "3a31c20a-01c2-4955-b239-dfb215f310b5",                        [{"hovertemplate":"\uc2dc\uc810=%{x}<br>\ucd1d\uc9c0\uc218=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":["2010. 01","2010. 02","2010. 03","2010. 04","2010. 05","2010. 06","2010. 07","2010. 08","2010. 09","2010. 10","2010. 11","2010. 12","2011. 01","2011. 02","2011. 03","2011. 04","2011. 05","2011. 06","2011. 07","2011. 08","2011. 09","2011. 10","20
# ...

# %%
all_consumer_gr=all_consumer.groupby("연도").mean().reset_index()
all_consumer_gr
# Out:
#       연도          전국       서울특별시       부산광역시       대구광역시       인천광역시  \
# 0   2010   91.051250   90.145583   90.235167   90.222750   91.593417
# 1   2011   94.716833   93.586250   94.257500   93.967167   94.723000
# 2   2012   96.788500   95.908000   96.513667   96.267833   96.601667
# 3   2013   98.048083   97.245417   97.937500   97.858667   97.648083
# 4   2014   99.297917   98.760500   99.167750   99.263250   99.018417
# 5   2015   99.999167   99.999167   99.999167  100.000000   99.998333
# 6   2016  100.970833  101.179167  101.182500  101.003333  100.854167
# 7   2017  102.934167  103.200000  102.986667  103.063333  102.765833
# 8   2018  104.453333  104.581667  104.784167  104.850833  104.430000
# 9   2019  104.853333  105.198333  105.290833  105.552500  104.706667
# 10  2020  105.416667  105.852500  105.476667  105.860000  105.527500
# 11  2021  107.511111  107.428889  107.608889  108.076667  107.636667
#
# ...

# %%
fresh_gr=fresh.groupby("연도").mean().reset_index()
fresh_gr
# Out:
#       연도         총지수        신선식품        신선어개        신선채소        신선과실  \
# 0   2010   91.051250   97.182750   87.929417  109.233833   94.271583
# 1   2011   94.716833  103.280500   95.645333  104.153917  107.769417
# 2   2012   96.788500  109.329500   97.170167  109.615167  118.439583
# 3   2013   98.048083  107.906000   96.831667  111.260083  113.755500
# 4   2014   99.297917   97.910000   98.384333   92.152833  105.128000
# 5   2015   99.999167  100.000000  100.000833   99.999167  100.000000
# 6   2016  100.970833  106.488333  103.133333  117.191667   98.370833
# 7   2017  102.934167  113.141667  108.772500  116.034167  113.125833
# 8   2018  104.453333  117.229167  111.481667  122.044167  116.200000
# 9   2019  104.853333  111.215833  110.780000  111.591667  111.130833
# 10  2020  105.416667  121.222500  118.904167  128.617500  115.385833
# 11  2021  107.511111  130.742222  120.027778  133.528889  134.990000
#
#         신선식품제외
# 0    90.845667
# 1    94.412083
# 2    96.318583
# ...

# %%
import plotly.express as px
fig = px.bar(all_consumer_gr, x='연도', y='전국',
            color='연도',
             labels={"전국 소비자 물가지수"}, height=600, width=1000)
fig.show()
# Out:
# <div>                            <div id="61bfb9ed-b594-4f04-815c-9b77cfab1092" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61bfb9ed-b594-4f04-815c-9b77cfab1092")) {                    Plotly.newPlot(                        "61bfb9ed-b594-4f04-815c-9b77cfab1092",                        [{"alignmentgroup":"True","hovertemplate":"\uc5f0\ub3c4=%{x}<br>\uc804\uad6d=%{y}<extra></extra>","legendgroup":"2010","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2010","offsetgroup":"2010","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["2010"],"xaxis":"x","y":[91.05125],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"\uc5f0\ub3c4=%{x}<br>\uc804\uad6d=%{y}<extra></extra>","legendgroup":"2011","marker":{"color":
# ...

# %%
import plotly.express as px
fig = px.bar(fresh_gr, x='연도', y='총지수',
            color='연도',
             labels={"전국 신선식품지수"}, height=600, width=1000)
fig.show()
# Out:
# <div>                            <div id="b72ae445-ec4c-4efc-81cd-683f69402e94" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b72ae445-ec4c-4efc-81cd-683f69402e94")) {                    Plotly.newPlot(                        "b72ae445-ec4c-4efc-81cd-683f69402e94",                        [{"alignmentgroup":"True","hovertemplate":"\uc5f0\ub3c4=%{x}<br>\ucd1d\uc9c0\uc218=%{y}<extra></extra>","legendgroup":"2010","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2010","offsetgroup":"2010","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["2010"],"xaxis":"x","y":[91.05125],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"\uc5f0\ub3c4=%{x}<br>\ucd1d\uc9c0\uc218=%{y}<extra></extra>","legendgroup":"2011","marke
# ...

# %%
import plotly.express as px
fig = px.bar(fresh_gr, x='연도', y='신선채소',
            color='연도',
             labels={"전국 신선채소_과실지수"}, height=600, width=1000)
fig.show()
# 배추가격 2014년 43% 폭락… 채소값 떨어져 물가상승률 낮춰
# Out:
# <div>                            <div id="60660b91-2030-4b8a-a656-7fc9b801110a" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60660b91-2030-4b8a-a656-7fc9b801110a")) {                    Plotly.newPlot(                        "60660b91-2030-4b8a-a656-7fc9b801110a",                        [{"alignmentgroup":"True","hovertemplate":"\uc5f0\ub3c4=%{x}<br>\uc2e0\uc120\ucc44\uc18c=%{y}<extra></extra>","legendgroup":"2010","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2010","offsetgroup":"2010","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["2010"],"xaxis":"x","y":[109.23383333333334],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"\uc5f0\ub3c4=%{x}<br>\uc2e0\uc120\ucc44\uc18c=%{y}<extra></extra>","lege
# ...

# %%
fig = px.line(all_consumer_gr, x="연도", y="전국")

fig.show()
# Out:
# <div>                            <div id="35c35d84-d9c8-4a26-bad9-fdb39ad563aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35c35d84-d9c8-4a26-bad9-fdb39ad563aa")) {                    Plotly.newPlot(                        "35c35d84-d9c8-4a26-bad9-fdb39ad563aa",                        [{"hovertemplate":"\uc5f0\ub3c4=%{x}<br>\uc804\uad6d=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[91.05125,94.71683333333334,96.7885,98.04808333333334,99.29791666666667,99.99916666666667,100.97083333333335,102.93416666666667,104.45333333333333,104
# ...

# %%
fig = px.line(fresh_gr, x="연도", y="총지수")

fig.show()
# Out:
# <div>                            <div id="62ee403f-2a52-426e-99e7-f0d433826131" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62ee403f-2a52-426e-99e7-f0d433826131")) {                    Plotly.newPlot(                        "62ee403f-2a52-426e-99e7-f0d433826131",                        [{"hovertemplate":"\uc5f0\ub3c4=%{x}<br>\ucd1d\uc9c0\uc218=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[91.05125,94.71683333333334,96.7885,98.04808333333334,99.29791666666667,99.99916666666667,100.97083333333335,102.93416666666667,104.453333333333
# ...

# %%
# import os
# os.getcwd()
# dir_path = "./project_data/data/" # 파일위치 폴더 
# fd_filenm = os.listdir(dir_path) # 모든 파일명 리스트를 가져옴
# fd_filenm=[f_nm for f_nm in fd_filenm if f_nm[-3:]=='xls']

# %%
# df=concat_read_file(fd_filenm)
